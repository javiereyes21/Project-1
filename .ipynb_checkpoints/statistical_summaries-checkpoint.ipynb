# %%
#dependencies
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cleaned_device_data = pd.read_csv("cleaned_device_data.csv")
cleaned_device_data
# Out:
#       UserID       DeviceType  UsageHoursPerDay  EnergyConsumption  \
# 0          1    Smart Speaker         15.307188           1.961607
# 1          2           Camera         19.973343           8.610689
# 2          3  Security System         18.911535           2.651777
# 3          4           Camera          7.011127           2.341653
# 4          5           Camera         22.610684           4.859069
# ...      ...              ...               ...                ...
# 5398    5399       Thermostat          4.556314           5.871764
# 5399    5400           Lights          0.561856           1.555992
# 5400    5401    Smart Speaker         11.096236           7.677779
# 5401    5402  Security System          8.782169           7.467929
# 5402    5403       Thermostat         13.540381           9.043076
#
#       UserPreferences  MalfunctionIncidents  DeviceAgeMonths  \
# 0                   1                     4               36
# ...

# %%
# #Statistical summary (Mean, Median, Var, StdDev, SEM)UsageHoursPerDay

# # Calculate Mean 
usage_mean = cleaned_device_data['UsageHoursPerDay'].mean()

# # Calculate Median
usage_median = cleaned_device_data['UsageHoursPerDay'].median()

# # Calculate Variance
usage_variance = np.var(cleaned_device_data['UsageHoursPerDay'])

# # Calculate Standard Deviation
usage_std_dev = np.std(cleaned_device_data['UsageHoursPerDay'])

# # Calculate Standard Error of the Mean (SEM)
usage_sem = usage_std_dev / np.sqrt(len(cleaned_device_data))

print (usage_mean)
print (usage_median)
print(usage_variance)
print(usage_std_dev)
print(usage_sem)
# Out:
# 12.052992010476402
# 11.90376845
# 45.08235183991478
# 6.714339270539938
# 0.09134521414562334

# %%
usage_stats = pd.DataFrame({
    'Statistic': ['Mean', 'Median', 'Variance', 'Standard Deviation', 'SEM'],
    'Value': [usage_mean, usage_median, usage_variance, usage_std_dev, usage_sem]
})

plt.figure(figsize=(8, 4))
plt.bar(usage_stats['Statistic'], usage_stats['Value'], color='skyblue')
plt.xlabel('Statistics', fontweight='bold')
plt.ylabel('Values')
plt.title('Hours Per Day Usage', fontweight='bold')
plt.savefig('usage_stats', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Statistical summary (Mean, Median, Var, StdDev, SEM)EnergyConsumption/HR
# Calculate Mean 
consumption_mean = cleaned_device_data['EnergyConsumption'].mean()

# Calculate Median
consumption_median = cleaned_device_data['EnergyConsumption'].median()

# Calculate Variance
consumption_variance = np.var(cleaned_device_data['EnergyConsumption'])

# Calculate Standard Deviation
consumption_std_dev = np.std(cleaned_device_data['EnergyConsumption'])

# Calculate Standard Error of the Mean (SEM)
consumption_sem = consumption_std_dev / np.sqrt(len(cleaned_device_data))

print (consumption_mean)
print (consumption_median)
print(consumption_variance)
print(consumption_std_dev)
print(consumption_sem)
# Out:
# 5.054301881356284
# 5.007047306
# 8.286767988255349
# 2.8786746930237443
# 0.0391629236615407

# %%
consumption_stats = pd.DataFrame({
    'Statistic': ['Mean', 'Median', 'Variance', 'Standard Deviation', 'SEM'],
    'Value': [consumption_mean, consumption_median, consumption_variance, consumption_std_dev, consumption_sem]
})

plt.figure(figsize=(8, 4))
plt.bar(consumption_stats['Statistic'], consumption_stats['Value'], color='orange')
plt.xlabel('Statistics', fontweight='bold')
plt.ylabel('Values')
plt.title('Energy Consumption', fontweight='bold')
plt.savefig('consumption_stats', dpi=300, bbox_inches='tight')
#plt.tight_layout
plt.show()

# %%
#Statistical summary (Mean, Median, Var, StdDev, SEM)DeviceAgeMonths

# Calculate Mean 
age_mean = cleaned_device_data['DeviceAgeMonths'].mean()

# Calculate Median
age_median = cleaned_device_data['DeviceAgeMonths'].median()

# Calculate Variance
age_variance = np.var(cleaned_device_data['DeviceAgeMonths'])

# Calculate Standard Deviation
age_std_dev = np.std(cleaned_device_data['DeviceAgeMonths'])

# Calculate Standard Error of the Mean (SEM)
age_sem = age_std_dev / np.sqrt(len(cleaned_device_data))

print (age_mean)
print (age_median)
print(age_variance)
print(age_std_dev)
print(age_sem)
# Out:
# 30.312233944105127
# 30.0
# 288.62451625695013
# 16.98895277104949
# 0.23112617138523045

# %%
age_stats = pd.DataFrame({
    'Statistic': ['Mean', 'Median', 'Variance', 'Standard Deviation', 'SEM'],
    'Value': [age_mean, age_median, age_variance, age_std_dev, age_sem]
})

plt.figure(figsize=(8, 4))
plt.bar(age_stats['Statistic'], age_stats['Value'], color='lightgreen')
plt.xlabel('Statistics', fontweight='bold')
plt.ylabel('Values')
plt.title('Device Age', fontweight='bold')
plt.savefig('age_stats.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
grouped_data = cleaned_device_data.groupby("DeviceType").agg(["mean", "median", "var", "std", "sem"])
grouped_data = grouped_data.reset_index()

# %%
melted_data = grouped_data.melt(id_vars='DeviceType', var_name=['Metric', 'Stat'], value_name='Value')

plt.figure(figsize=(10, 8))
sns.barplot(x='DeviceType', y='Value', hue='Stat', data=melted_data,)

plt.title('Aggregated Statistics by DeviceType', fontweight='bold')
plt.xlabel('Device Type')
plt.ylabel('Value')
plt.legend(title='Statistic', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=5)
plt.tight_layout()

plt.show()

# %%
device_df = {
    'DeviceType': ['Camera','Lights', 'Security System', 'Smart Speaker', 'Thermostat'],
    'UsageHoursPerDay': [1, 5, 10, 20, 30,]
}
cleaned_device_df = pd.DataFrame(device_df)

# Plotting the histogram
plt.figure(figsize=(10, 8))


sns.histplot(data=cleaned_device_df, x='UsageHoursPerDay', hue='DeviceType', multiple='stack', bins=7)

# Customize the plot
plt.title('Usage Hours Per Day by Device Type', fontweight="bold")
plt.xlabel('Usage Hours Per Day')
plt.ylabel('Frequency')
handles, labels = hist.get_legend_handles_labels()
plt.legend(handles=handles, labels=labels, title='Device Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.legend(title='DeviceType', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
# Out:
# C:\Users\javie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 17
#      15 plt.xlabel('Usage Hours Per Day')
#      16 plt.ylabel('Frequency')
# ---> 17 handles, labels = hist.get_legend_handles_labels()
#      18 plt.legend(handles=handles, labels=labels, title='Device Type', bbox_to_anchor=(1.05, 1), loc='upper left')
#      19 plt.tight_layout()
#
# NameError: name 'hist' is not defined

# %%
cleaned_device_data.describe()
